# %% [markdown]
# # Sales Forecasting — EDA & Trend Analysis
#
# Interactive exploration of the sales time-series before modeling.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

import pandas as pd
import matplotlib.pyplot as plt

from config import RAW_DATA_PATH, DATE_COL, TARGET_COL
from src.generate_dataset import save_dataset
from src.data_cleaning import load_and_clean
from src.eda import run_eda

# %%
if not RAW_DATA_PATH.exists():
    save_dataset()

df = load_and_clean(RAW_DATA_PATH)
df.head()
# Out:
#         date   sales  units_sold region
# 0 2022-01-01  793.08          41  South
# 1 2022-01-02  976.23          54  South
# 2 2022-01-03  929.69          41  South
# 3 2022-01-04  951.09          37  North
# 4 2022-01-05  779.79          30   East

# %%
summary = run_eda(df, save_plots=True)
pd.Series(summary)
# Out:
# n_observations                         730
# date_range        2022-01-01 to 2023-12-31
# mean_sales                          953.36
# std_sales                           166.19
# min_sales                           542.08
# max_sales                          1617.46
# mom_growth_pct                       23.36
# dtype: object

# %%
from IPython.display import Image, display
from config import FIGURES_DIR

for img in sorted(FIGURES_DIR.glob("*.png")):
    print(img.name)
    display(Image(filename=str(img)))
# Out:
# 01_time_series.png
# 02_distribution_seasonality.png
# 03_decomposition.png
# 04_model_forecasts.png
# 05_metrics_comparison.png
